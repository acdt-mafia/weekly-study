# %% [markdown]
# **Recommended to run on Google Colab.**

# %%
# !pip install transformers

# %%
from transformers import GPT2LMHeadModel

model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
model # print(model) 해도 출력 결과는 동일

# %%
"""
# To-Do 1: LMHeadModel의 가장 마지막 레이어(lm_head)에 들어있는 weight 행렬의 크기(=행의 개수, 열의 개수)를 출력해보세요.

- lm_head는 우리가 배웠던 MLP이고, MLP는 입력 벡터에 **행렬곱** 연산을 수행하는 것과 같습니다.
  - 행렬곱이 된다고 명확히 예시를 다 보여드리진 못했지만 아마 이 부분은 자습으로 커버가 가능할 겁니다 화이팅 !!
- 따라서 lm_head에도 하나의 큰 행렬이 (Torch.Tensor 자료형으로) 존재합니다.
- 이 lm_head 레이어에 들어있는 weight 행렬의 크기(행 개수와 열 개수) print() 함수로 직접 출력해보세요.
  - MLP에는 weight도 있고 bias도 있지만, 지금은 weight 행렬만을 다룹니다.
  - Torch.Tensor 변수는 .shape 이라는 메소드를 사용해서 행, 열의 개수를 확인할 수 있다는 점을 이용하세요.
"""

# 정답 형태: torch.Size([행 개수, 열 개수])

# %%
"""
# To-Do 2: lm_head의 weight 행렬에서 첫 번째 행에 해당하는 벡터를 print() 함수로 출력해보세요.
"""

# 정답 형태: tensor([...])
